# %%
print "hola mundo"
# Out:
#   Cell In[1], line 1
#     print "hola mundo"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print ("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# Hola Mundo

# %% [markdown]
# ##Mis primeros pasos en Markdown...

# %%
... Son muy buenos
# Out:
#   Cell In[1], line 1
#     ... Son muy buenos
#         ^
# SyntaxError: invalid syntax
